# %%
from typing import List, Dict

import requests
import IPython


class Pokemon:
    name_url_dict = {
        d["name"]: d["url"]
        for d in requests.get(
            "https://pokeapi.co/api/v2/pokemon"
        ).json()["results"]
    }

    names = name_url_dict.keys()
    urls = name_url_dict.values()

    def __init__(self, name):
        self.name = name
        self.url = "https://pokeapi.co/api/v2/pokemon" + name

    @property
    def keys(self):
        return requests.get(
            self.url
        ).json().keys()

    @property
    def values(self):
        return requests.get(
            self.url
        ).json().values()

    @property
    def items(self):
        return requests.get(
            self.url
        ).json().items()

    @property
    def abilities(self) -> List:
        return requests.get(
            self.url
        ).json()["abilities"]

    @property
    def ability_names(self) -> List:
        return [
            d["ability"]["name"]
            for d in requests.get(
                self.url
            ).json()["abilities"]
        ]

    @property
    def base_experience(self) -> int:
        return requests.get(
            self.url
        ).json()["base_experience"]

    @property
    def forms(self) -> List:
        return requests.get(
            self.url
        ).json()["forms"]

    @property
    def game_indices(self) -> List:
        return requests.get(
            self.url
        ).json()["game_indices"]

    @property
    def held_items(self) -> List:
        return requests.get(
            self.url
        ).json()["held_items"]

    @property
    def height(self) -> int:
        return requests.get(
            self.url
        ).json()["height"]

    @property
    def id(self) -> int:
        return requests.get(
            self.url
        ).json()["id"]

    @property
    def is_default(self) -> bool:
        return requests.get(
            self.url
        ).json()["is_default"]

    @property
    def location_area_encounters(self) -> str:
        return requests.get(
            self.url
        ).json()["location_area_encounters"]

    @property
    def moves(self) -> List:
        return requests.get(
            self.url
        ).json()["moves"]

    @property
    def move_names(self) -> List:
        return [
            d["move"]["name"]
            for d in requests.get(
                self.url
            ).json()["moves"]
        ]

    @property
    def order(self) -> int:
        return requests.get(
            self.url
        ).json()["order"]

    @property
    def species(self) -> Dict:
        return requests.get(
            self.url
        ).json()["species"]

    @property
    def sprites(self) -> Dict:
        return requests.get(
            self.url
        ).json()["sprites"]

    @property
    def sprite_options(self):
        return requests.get(
            self.url
        ).json()["sprites"].keys()

    @property
    def stats(self) -> List:
        return requests.get(
            self.url
        ).json()["stats"]

    @property
    def types(self) -> List:
        return requests.get(
            self.url
        ).json()["types"]

    @property
    def weight(self) -> int:
        return requests.get(
            self.url
        ).json()["weight"]

    def get_ability(self, ability_name: str) -> Dict:
        return {
            d["ability"]["name"]: d["ability"]
            for d in
            requests.get(
                self.url
            ).json()["abilities"]
        }[ability_name]

    def get_move(self, move_name: str) -> Dict:
        return {
            d["move"]["name"]: d["move"]
            for d in
            requests.get(
                self.url
            ).json()["moves"]
        }[move_name]

    def get_sprite(
            self,
            sprite_option: str = "front_default"
    ) -> IPython.core.display.Image:
        return IPython.display.Image(requests.get(
            self.url
        ).json()["sprites"][sprite_option])

b = Pokemon("bulbasaur")

# %%
from typing import List, Dict

# %%
import requests
import IPython
from IPython.display import Image

# %%
request_data = requests.get("https://pokeapi.co/api/v2/pokemon/pikachu")

# %%
Image(request_data.json()["sprites"]["front_female"])

# %%
Image(request_data.json()["sprites"]["front_default"])

# %%
class Pokemon:
    name_url_dict = {
        d["name"]: d["url"]
        for d in requests.get(
            "https://pokeapi.co/api/v2/pokemon"
        ).json()["results"]
    }

    names = name_url_dict.keys()
    urls = name_url_dict.values()

    def __init__(self, name):
        self.name = name
        self.url = self.__class__.name_url_dict[name]

    @property
    def keys(self):
        return requests.get(
            self.url
        ).json().keys()

    @property
    def values(self):
        return requests.get(
            self.url
        ).json().values()

    @property
    def items(self):
        return requests.get(
            self.url
        ).json().items()

    @property
    def abilities(self) -> List:
        return requests.get(
            self.url
        ).json()["abilities"]

    @property
    def ability_names(self) -> List:
        return [
            d["ability"]["name"]
            for d in requests.get(
                self.url
            ).json()["abilities"]
        ]

    @property
    def base_experience(self) -> int:
        return requests.get(
            self.url
        ).json()["base_experience"]

    @property
    def forms(self) -> List:
        return requests.get(
            self.url
        ).json()["forms"]

    @property
    def game_indices(self) -> List:
        return requests.get(
            self.url
        ).json()["game_indices"]

    @property
    def held_items(self) -> List:
        return requests.get(
            self.url
        ).json()["held_items"]

    @property
    def height(self) -> int:
        return requests.get(
            self.url
        ).json()["height"]

    @property
    def id(self) -> int:
        return requests.get(
            self.url
        ).json()["id"]

    @property
    def is_default(self) -> bool:
        return requests.get(
            self.url
        ).json()["is_default"]

    @property
    def location_area_encounters(self) -> str:
        return requests.get(
            self.url
        ).json()["location_area_encounters"]

    @property
    def moves(self) -> List:
        return requests.get(
            self.url
        ).json()["moves"]

    @property
    def move_names(self) -> List:
        return [
            d["move"]["name"]
            for d in requests.get(
                self.url
            ).json()["moves"]
        ]

    @property
    def order(self) -> int:
        return requests.get(
            self.url
        ).json()["order"]

    @property
    def species(self) -> Dict:
        return requests.get(
            self.url
        ).json()["species"]

    @property
    def sprites(self) -> Dict:
        return requests.get(
            self.url
        ).json()["sprites"]

    @property
    def sprite_options(self):
        return requests.get(
            self.url
        ).json()["sprites"].keys()

    @property
    def stats(self) -> List:
        return requests.get(
            self.url
        ).json()["stats"]

    @property
    def types(self) -> List:
        return requests.get(
            self.url
        ).json()["types"]

    @property
    def weight(self) -> int:
        return requests.get(
            self.url
        ).json()["weight"]

    def get_ability(self, ability_name: str) -> Dict:
        return {
            d["ability"]["name"]: d["ability"]
            for d in
            requests.get(
                self.url
            ).json()["abilities"]
        }[ability_name]

    def get_move(self, move_name: str) -> Dict:
        return {
            d["move"]["name"]: d["move"]
            for d in
            requests.get(
                self.url
            ).json()["moves"]
        }[move_name]

    def get_sprite(
            self,
            sprite_option: str = "front_default"
    ) -> IPython.core.display.Image:
        return IPython.display.Image(requests.get(
            self.url
        ).json()["sprites"][sprite_option])

b = Pokemon("bulbasaur")

# %%
from typing import List, Dict, KeysView, ItemsView, ValuesView

import requests
import IPython


class Pokemon:
    
    def __init__(self, name):
        self.name = name
        self.url = "https://pokeapi.co/api/v2/pokemon/" + name

    @property
    def keys(self) -> KeysView:
        return requests.get(self.url).json().keys()

    @property
    def values(self) -> ValuesView:
        return requests.get(self.url).json().values()

    @property
    def items(self) -> ItemsView:
        return requests.get(self.url).json().items()

    @property
    def abilities(self) -> List:
        return requests.get(self.url).json()["abilities"]

    @property
    def ability_names(self) -> List:
        return [
            d["ability"]["name"]
            for d in requests.get(
                self.url
            ).json()["abilities"]
        ]

    @property
    def base_experience(self) -> int:
        return requests.get(self.url).json()["base_experience"]

    @property
    def forms(self) -> List:
        return requests.get(self.url).json()["forms"]

    @property
    def game_indices(self) -> List:
        return requests.get(self.url).json()["game_indices"]

    @property
    def held_items(self) -> List:
        return requests.get(self.url).json()["held_items"]

    @property
    def height(self) -> int:
        return requests.get(self.url).json()["height"]

    @property
    def id(self) -> int:
        return requests.get(self.url).json()["id"]

    @property
    def is_default(self) -> bool:
        return requests.get(self.url).json()["is_default"]

    @property
    def location_area_encounters(self) -> str:
        return requests.get(
            self.url
        ).json()["location_area_encounters"]

    @property
    def moves(self) -> List:
        return requests.get(self.url).json()["moves"]

    @property
    def move_names(self) -> List:
        return [
            d["move"]["name"]
            for d in requests.get(
                self.url
            ).json()["moves"]
        ]

    @property
    def order(self) -> int:
        return requests.get(self.url).json()["order"]

    @property
    def species(self) -> Dict:
        return requests.get(self.url).json()["species"]

    @property
    def sprites(self) -> Dict:
        return requests.get(self.url).json()["sprites"]

    @property
    def sprite_options(self) -> KeysView:
        return requests.get(self.url).json()["sprites"].keys()

    @property
    def stats(self) -> List:
        return requests.get(self.url).json()["stats"]

    @property
    def types(self) -> List:
        return requests.get(self.url).json()["types"]

    @property
    def weight(self) -> int:
        return requests.get(self.url).json()["weight"]

    def get_ability(self, ability_name: str) -> Dict:
        return {
            d["ability"]["name"]: d["ability"]
            for d in
            requests.get(
                self.url
            ).json()["abilities"]
        }[ability_name]

    def get_move(self, move_name: str) -> Dict:
        return {
            d["move"]["name"]: d["move"]
            for d in
            requests.get(
                self.url
            ).json()["moves"]
        }[move_name]

    def get_sprite(
            self,
            sprite_option: str = "front_default"
    ) -> IPython.core.display.Image:
        return IPython.display.Image(requests.get(
            self.url
        ).json()["sprites"][sprite_option])

if __name__ == '__main__':
    b = Pokemon("bulbasaur")
    b.get_ability(b.ability_names[0])
    b.get_move(b.move_names[0])
    b.get_sprite()

# %%
b = Pokemon("bulbasaur")

# %%
b.ability_names
# Out:
# ['chlorophyll', 'overgrow']

# %%
b.get_ability(b.ability_names[0])
# Out:
# {'name': 'chlorophyll', 'url': 'https://pokeapi.co/api/v2/ability/34/'}

# %%
b.move_names
# Out:
# ['razor-wind',
#  'swords-dance',
#  'cut',
#  'bind',
#  'vine-whip',
#  'headbutt',
#  'tackle',
#  'body-slam',
#  'take-down',
#  'double-edge',
#  'growl',
#  'strength',
#  'mega-drain',
#  'leech-seed',
#  'growth',
#  'razor-leaf',
#  'solar-beam',
#  'poison-powder',
#  'sleep-powder',
#  'petal-dance',
#  'string-shot',
#  'toxic',
#  'rage',
#  'mimic',
#  'double-team',
#  'defense-curl',
#  'light-screen',
#  'reflect',
#  'bide',
#  'sludge',
#  'skull-bash',
#  'amnesia',
#  'flash',
#  'rest',
#  'substitute',
#  'snore',
#  'curse',
#  'protect',
#  'sludge-bomb',
#  'mud-slap',
#  'giga-drain',
#  'endure',
#  'charm',
#  'swagger',
#  'fury-cutter',
#  'attract',
#  'sleep-talk',
#  'return',
#  'frustration',
#  'safeguard',
#  'sweet-scent',
#  'synthesis',
#  'hidden-power',
#  'sunny-day',
#  'rock-smash',
#  'facade',
#  'nature-power',
#  'ingrain',
#  'knock-off',
#  'secret-power',
#  'grass-whistle',
#  'bullet-seed',
#  'magical-leaf',
#  'natural-gift',
#  'worry-seed',
#  'seed-bomb',
#  'energy-ball',
#  'leaf-storm',
#  'power-whip',
#  'captivate',
#  'grass-knot',
#  'venoshock',
#  'round',
#  'echoed-voice',
#  'grass-pledge',
#  'work-up',
#  'grassy-terrain',
#  'confide']

# %%
b.get_sprite()

# %%
p = Pokemon("bulbasaur")
powers = {
    p.move_name[i]: requests.get(p.get_move(p.move_names[i])["url"]).json()["power"]
    for i in range(10)
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-eca4e0b29735> in <module>
#       2 powers = {
#       3     p.move_name[i]: requests.get(p.get_move(p.move_names[i])["url"]).json()["power"]
# ----> 4     for i in range(10)
#       5 }
#
# <ipython-input-34-eca4e0b29735> in <dictcomp>(.0)
#       2 powers = {
#       3     p.move_name[i]: requests.get(p.get_move(p.move_names[i])["url"]).json()["power"]
# ----> 4     for i in range(10)
#       5 }
#
# AttributeError: 'Pokemon' object has no attribute 'move_name'

# %%
requests.get(p.get_move(p.move_names[i])["url"]).json()["power"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-78e783b18c71> in <module>
# ----> 1 requests.get(p.get_move(p.move_names[i])["url"]).json()["power"]
#
# NameError: name 'i' is not defined

# %%
import pandas as pdimport matplotlib.pyplot as pltdf = pd.DataFrame(    powers,    index=[p.name]).melt(    var_name="move",    value_name="power").set_index("move")df.plot.barh(legend=False)plt.suptitle(f"Power values for {p.name}")plt.title(f"Obtained from {p.url}");
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/inputtransformer2.py:481: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")
#   File "<ipython-input-36-cc8eedf5673b>", line 1
#     import pandas as pd
#
# ^
# SyntaxError: invalid character in identifier

# %%
import pandas as pd

import matplotlib.pyplot as plt

df = pd.DataFrame(
    powers,
    index=[p.name]
).melt(
    var_name="move",
    value_name="power"
).set_index("move")

df.plot.barh(legend=False)
plt.suptitle(f"Power values for {p.name}")
plt.title(f"Obtained from {p.url}");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-91267f28d0b5> in <module>
#       4
#       5 df = pd.DataFrame(
# ----> 6     powers,
#       7     index=[p.name]
#       8 ).melt(
#
# NameError: name 'powers' is not defined

# %%
from typing import List, Dict, KeysView, ItemsView, ValuesView

import requests
import IPython
import pandas as pd
import matplotlib.pyplot as plt

class Pokemon:
    
    def __init__(self, name) -> None:
        self.name = name
        self.url = "https://pokeapi.co/api/v2/pokemon/" + name

    @property
    def keys(self) -> KeysView:
        return requests.get(self.url).json().keys()

    @property
    def values(self) -> ValuesView:
        return requests.get(self.url).json().values()

    @property
    def items(self) -> ItemsView:
        return requests.get(self.url).json().items()

    @property
    def abilities(self) -> List:
        return requests.get(self.url).json()["abilities"]

    @property
    def ability_names(self) -> List:
        return [
            d["ability"]["name"]
            for d in requests.get(
                self.url
            ).json()["abilities"]
        ]

    @property
    def base_experience(self) -> int:
        return requests.get(self.url).json()["base_experience"]

    @property
    def forms(self) -> List:
        return requests.get(self.url).json()["forms"]

    @property
    def game_indices(self) -> List:
        return requests.get(self.url).json()["game_indices"]

    @property
    def held_items(self) -> List:
        return requests.get(self.url).json()["held_items"]

    @property
    def height(self) -> int:
        return requests.get(self.url).json()["height"]

    @property
    def id(self) -> int:
        return requests.get(self.url).json()["id"]

    @property
    def is_default(self) -> bool:
        return requests.get(self.url).json()["is_default"]

    @property
    def location_area_encounters(self) -> str:
        return requests.get(
            self.url
        ).json()["location_area_encounters"]

    @property
    def moves(self) -> List:
        return requests.get(self.url).json()["moves"]

    @property
    def move_names(self) -> List:
        return [
            d["move"]["name"]
            for d in requests.get(
                self.url
            ).json()["moves"]
        ]
    
    @property
    def move_powers(self) -> List:
        return [
            requests.get(p.get_move(move)["url"]).json()["power"]
            for move in self.move_names
        ]

    @property
    def order(self) -> int:
        return requests.get(self.url).json()["order"]

    @property
    def species(self) -> Dict:
        return requests.get(self.url).json()["species"]

    @property
    def sprites(self) -> Dict:
        return requests.get(self.url).json()["sprites"]

    @property
    def sprite_options(self) -> KeysView:
        return requests.get(self.url).json()["sprites"].keys()

    @property
    def stats(self) -> List:
        return requests.get(self.url).json()["stats"]

    @property
    def types(self) -> List:
        return requests.get(self.url).json()["types"]

    @property
    def weight(self) -> int:
        return requests.get(self.url).json()["weight"]

    def get_ability(self, ability_name: str) -> Dict:
        return {
            d["ability"]["name"]: d["ability"]
            for d in
            requests.get(
                self.url
            ).json()["abilities"]
        }[ability_name]

    def get_move(self, move_name: str) -> Dict:
        return {
            d["move"]["name"]: d["move"]
            for d in
            requests.get(
                self.url
            ).json()["moves"]
        }[move_name]

    def get_sprite(
            self,
            sprite_option: str = "front_default"
    ) -> IPython.core.display.Image:
        return IPython.display.Image(requests.get(
            self.url
        ).json()["sprites"][sprite_option])

    
    def plot_move_powers(self, n=10, ascending=True):
        powers = dict(zip(p.move_names, p.move_powers))

        pd.DataFrame(
            powers,
            index=[p.name]
        ).melt(
            var_name="move",
            value_name="power"
        ).sort_values(
            by="power",
            ascending=ascending
        ).head(n).set_index("move").plot.barh(legend=False)
        
        plt.suptitle(f"Power values for {p.name}")
        plt.title(f"Obtained from {p.url}");
        
if __name__ == '__main__':
    b = Pokemon("bulbasaur")
    b.get_ability(b.ability_names[0])
    b.get_move(b.move_names[0])
    b.get_sprite()

# %%
from typing import List, Dict, KeysView, ItemsView, ValuesView

import requests
import IPython
import pandas as pd
import matplotlib.pyplot as plt

class Pokemon:
    
    def __init__(self, name) -> None:
        self.name = name
        self.url = "https://pokeapi.co/api/v2/pokemon/" + name

    @property
    def keys(self) -> KeysView:
        return requests.get(self.url).json().keys()

    @property
    def values(self) -> ValuesView:
        return requests.get(self.url).json().values()

    @property
    def items(self) -> ItemsView:
        return requests.get(self.url).json().items()

    @property
    def abilities(self) -> List:
        return requests.get(self.url).json()["abilities"]

    @property
    def ability_names(self) -> List:
        return [
            d["ability"]["name"]
            for d in requests.get(
                self.url
            ).json()["abilities"]
        ]

    @property
    def base_experience(self) -> int:
        return requests.get(self.url).json()["base_experience"]

    @property
    def forms(self) -> List:
        return requests.get(self.url).json()["forms"]

    @property
    def game_indices(self) -> List:
        return requests.get(self.url).json()["game_indices"]

    @property
    def held_items(self) -> List:
        return requests.get(self.url).json()["held_items"]

    @property
    def height(self) -> int:
        return requests.get(self.url).json()["height"]

    @property
    def id(self) -> int:
        return requests.get(self.url).json()["id"]

    @property
    def is_default(self) -> bool:
        return requests.get(self.url).json()["is_default"]

    @property
    def location_area_encounters(self) -> str:
        return requests.get(
            self.url
        ).json()["location_area_encounters"]

    @property
    def moves(self) -> List:
        return requests.get(self.url).json()["moves"]

    def get_move_names(self, n) -> List:
        return [
            d["move"]["name"]
            for d in requests.get(
                self.url
            ).json()["moves"][:n]
        ]
    
    def get_move_powers(self, n) -> List:
        return [
            requests.get(p.get_move(move)["url"]).json()["power"]
            for move in self.get_move_names(n)
        ]

    @property
    def order(self) -> int:
        return requests.get(self.url).json()["order"]

    @property
    def species(self) -> Dict:
        return requests.get(self.url).json()["species"]

    @property
    def sprites(self) -> Dict:
        return requests.get(self.url).json()["sprites"]

    @property
    def sprite_options(self) -> KeysView:
        return requests.get(self.url).json()["sprites"].keys()

    @property
    def stats(self) -> List:
        return requests.get(self.url).json()["stats"]

    @property
    def types(self) -> List:
        return requests.get(self.url).json()["types"]

    @property
    def weight(self) -> int:
        return requests.get(self.url).json()["weight"]

    def get_ability(self, ability_name: str) -> Dict:
        return {
            d["ability"]["name"]: d["ability"]
            for d in
            requests.get(
                self.url
            ).json()["abilities"]
        }[ability_name]

    def get_move(self, move_name: str) -> Dict:
        return {
            d["move"]["name"]: d["move"]
            for d in
            requests.get(
                self.url
            ).json()["moves"]
        }[move_name]

    def get_sprite(
            self,
            sprite_option: str = "front_default"
    ) -> IPython.core.display.Image:
        return IPython.display.Image(requests.get(
            self.url
        ).json()["sprites"][sprite_option])

    
    def plot_move_powers(self, n=10, ascending=False):
        powers = dict(zip(p.get_move_names(n), p.get_move_powers(n)))

        pd.DataFrame(
            powers,
            index=[p.name]
        ).melt(
            var_name="move",
            value_name="power"
        ).sort_values(
            by="power",
            ascending=ascending
        ).head(n).set_index("move").plot.barh(legend=False)
        
        plt.suptitle(f"Power values for {p.name}")
        plt.title(f"Obtained from {p.url}");
